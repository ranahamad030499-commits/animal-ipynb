# %%
class Animal:
    def speak(self):
        return "sound of animal"


class Dog(Animal):
     pass

class Cat (Animal):
    pass

# %%
Animal = Animal()
print (Animal.speak()) 

dog = Dog()
print (dog.speak())

cat = Cat()
print (cat.speak())
# Out:
# sound of animal
# sound of animal
# sound of animal
